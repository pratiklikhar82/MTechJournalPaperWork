# %%
import cv2

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
## define color code for different classes

# %%
# Background - (1,1,1)
# 0 - (3,3,3)
# 1 - (5,5,5)
# 2 - (7,7,7)
# 3 - (9,9,9)
# 4 - (11,11,11)
# 5 - (13,13,13)
# 6 - (15,15,15)
# 7 - (17,17,17)
# 8 - (19,19,19)
# 9 - (21,21,21)
# A - (23,23,23)
# B - (25,25,25)
# C - (27,27,27)
# D - (29,29,29)
# E - (31,31,31)
# F - (33,33,33)
# G - (35,35,35)
# H - (37,37,37)
# I - (39,39,39)
# J - (41,41,41)
# K - (43,43,43)
# L - (45,45,45)
# M - (47,47,47)
# N - (49,49,49)
# O - (51,51,51)
# P - (53,53,53)
# Q - (55,55,55)
# R - (57,57,57)
# S - (59,59,59)
# T - (61,61,61)
# U - (63,63,63)
# V - (65,65,65)
# W - (67,67,67)
# X - (69,69,69)
# Y - (71,71,71)
# Z - (73,73,73)

# %%
# Dataprep for Masks Starts

# %%
root_dir = '/Users/pratiklikhar/Documents/MTech_Project'

# %%
import os

# %%
data_dir = os.path.join(root_dir,'Dataset','DatasetsCombined')

# %%
users = ['Naveen','Neel','Srujana','Vishnu']

# %%
# Dataprep for 0

# %%
count = 1
for user in users:
    image_dir = os.path.join(data_dir,user,'0','binary')
    image_list = os.listdir(image_dir)
    for image in image_list:
        im = cv2.imread(os.path.join(image_dir,image))
        Full_frame_mask=np.zeros([480,640,3],dtype="uint8")
        Full_frame_mask[190:400,190:500] = im
        ht = Full_frame_mask.shape[0]
        wd = Full_frame_mask.shape[1]
        for i in range(ht):
            for j in range(wd):
                if Full_frame_mask[i][j][0] == 255:
                    Full_frame_mask[i][j][0] = 3
                    Full_frame_mask[i][j][1] = 3
                    Full_frame_mask[i][j][2] = 3
                else:
                    Full_frame_mask[i][j][0] = 1
                    Full_frame_mask[i][j][1] = 1
                    Full_frame_mask[i][j][2] = 1
        cv2.imwrite(os.path.join(root_dir,'modified_dataset','masks')+'/0_'+str(count)+'.png', Full_frame_mask)
        print('image {} processed'.format(count))
        count += 1
    print('User {} processed'.format(user))
# Out:
# image 1 processed
# image 2 processed
# image 3 processed
# image 4 processed
# image 5 processed
# image 6 processed
# image 7 processed
# image 8 processed
# image 9 processed
# image 10 processed
# image 11 processed
# image 12 processed
# image 13 processed
# image 14 processed
# image 15 processed
# image 16 processed
# image 17 processed
# image 18 processed
# image 19 processed
# image 20 processed
# image 21 processed
# image 22 processed
# image 23 processed
# image 24 processed
# image 25 processed
# image 26 processed
# image 27 processed
# image 28 processed
# image 29 processed
# image 30 processed
# image 31 processed
# image 32 processed
# image 33 processed
# image 34 processed
# image 35 processed
# image 36 processed
# image 37 processed
# image 38 processed
# image 39 processed
# image 40 processed
# image 41 processed
# image 42 processed
# image 43 processed
# image 44 processed
# image 45 processed
# image 46 processed
# image 47 processed
# image 48 processed
# ...

# %%
# Dataprep for 1

# %%
count = 1
for user in users:
    image_dir = os.path.join(data_dir,user,'1','binary')
    image_list = os.listdir(image_dir)
    for image in image_list:
        im = cv2.imread(os.path.join(image_dir,image))
        Full_frame_mask=np.zeros([480,640,3],dtype="uint8")
        Full_frame_mask[190:400,190:500] = im
        ht = Full_frame_mask.shape[0]
        wd = Full_frame_mask.shape[1]
        for i in range(ht):
            for j in range(wd):
                if Full_frame_mask[i][j][0] == 255:
                    Full_frame_mask[i][j][0] = 5
                    Full_frame_mask[i][j][1] = 5
                    Full_frame_mask[i][j][2] = 5
                else:
                    Full_frame_mask[i][j][0] = 1
                    Full_frame_mask[i][j][1] = 1
                    Full_frame_mask[i][j][2] = 1
        cv2.imwrite(os.path.join(root_dir,'modified_dataset','masks')+'/1_'+str(count)+'.png', Full_frame_mask)
        print('image {} processed'.format(count))
        count += 1
    print('User {} processed'.format(user))
# Out:
# image 1 processed
# image 2 processed
# image 3 processed
# image 4 processed
# image 5 processed
# image 6 processed
# image 7 processed
# image 8 processed
# image 9 processed
# image 10 processed
# image 11 processed
# image 12 processed
# image 13 processed
# image 14 processed
# image 15 processed
# image 16 processed
# image 17 processed
# image 18 processed
# image 19 processed
# image 20 processed
# image 21 processed
# image 22 processed
# image 23 processed
# image 24 processed
# image 25 processed
# image 26 processed
# image 27 processed
# image 28 processed
# image 29 processed
# image 30 processed
# image 31 processed
# image 32 processed
# image 33 processed
# image 34 processed
# image 35 processed
# image 36 processed
# image 37 processed
# image 38 processed
# image 39 processed
# image 40 processed
# image 41 processed
# image 42 processed
# image 43 processed
# image 44 processed
# image 45 processed
# image 46 processed
# image 47 processed
# image 48 processed
# ...

# %%
count = 1
for user in users:
    image_dir = os.path.join(data_dir,user,'2','binary')
    image_list = os.listdir(image_dir)
    for image in image_list:
        im = cv2.imread(os.path.join(image_dir,image))
        Full_frame_mask=np.zeros([480,640,3],dtype="uint8")
        Full_frame_mask[190:400,190:500] = im
        ht = Full_frame_mask.shape[0]
        wd = Full_frame_mask.shape[1]
        for i in range(ht):
            for j in range(wd):
                if Full_frame_mask[i][j][0] == 255:
                    Full_frame_mask[i][j][0] = 7
                    Full_frame_mask[i][j][1] = 7
                    Full_frame_mask[i][j][2] = 7
                else:
                    Full_frame_mask[i][j][0] = 1
                    Full_frame_mask[i][j][1] = 1
                    Full_frame_mask[i][j][2] = 1
        cv2.imwrite(os.path.join(root_dir,'modified_dataset','masks')+'/2_'+str(count)+'.png', Full_frame_mask)
        print('image {} processed'.format(count))
        count += 1
    print('User {} processed'.format(user))
# Out:
# image 1 processed
# image 2 processed
# image 3 processed
# image 4 processed
# image 5 processed
# image 6 processed
# image 7 processed
# image 8 processed
# image 9 processed
# image 10 processed
# image 11 processed
# image 12 processed
# image 13 processed
# image 14 processed
# image 15 processed
# image 16 processed
# image 17 processed
# image 18 processed
# image 19 processed
# image 20 processed
# image 21 processed
# image 22 processed
# image 23 processed
# image 24 processed
# image 25 processed
# image 26 processed
# image 27 processed
# image 28 processed
# image 29 processed
# image 30 processed
# image 31 processed
# image 32 processed
# image 33 processed
# image 34 processed
# image 35 processed
# image 36 processed
# image 37 processed
# image 38 processed
# image 39 processed
# image 40 processed
# image 41 processed
# image 42 processed
# image 43 processed
# image 44 processed
# image 45 processed
# image 46 processed
# image 47 processed
# image 48 processed
# ...

# %%
count = 1
for user in users:
    image_dir = os.path.join(data_dir,user,'3','binary')
    image_list = os.listdir(image_dir)
    for image in image_list:
        im = cv2.imread(os.path.join(image_dir,image))
        Full_frame_mask=np.zeros([480,640,3],dtype="uint8")
        Full_frame_mask[190:400,190:500] = im
        ht = Full_frame_mask.shape[0]
        wd = Full_frame_mask.shape[1]
        for i in range(ht):
            for j in range(wd):
                if Full_frame_mask[i][j][0] == 255:
                    Full_frame_mask[i][j][0] = 9
                    Full_frame_mask[i][j][1] = 9
                    Full_frame_mask[i][j][2] = 9
                else:
                    Full_frame_mask[i][j][0] = 1
                    Full_frame_mask[i][j][1] = 1
                    Full_frame_mask[i][j][2] = 1
        cv2.imwrite(os.path.join(root_dir,'modified_dataset','masks')+'/3_'+str(count)+'.png', Full_frame_mask)
        print('image {} processed'.format(count))
        count += 1
    print('User {} processed'.format(user))
# Out:
# image 1 processed
# image 2 processed
# image 3 processed
# image 4 processed
# image 5 processed
# image 6 processed
# image 7 processed
# image 8 processed
# image 9 processed
# image 10 processed
# image 11 processed
# image 12 processed
# image 13 processed
# image 14 processed
# image 15 processed
# image 16 processed
# image 17 processed
# image 18 processed
# image 19 processed
# image 20 processed
# image 21 processed
# image 22 processed
# image 23 processed
# image 24 processed
# image 25 processed
# image 26 processed
# image 27 processed
# image 28 processed
# image 29 processed
# image 30 processed
# image 31 processed
# image 32 processed
# image 33 processed
# image 34 processed
# image 35 processed
# image 36 processed
# image 37 processed
# image 38 processed
# image 39 processed
# image 40 processed
# image 41 processed
# image 42 processed
# image 43 processed
# image 44 processed
# image 45 processed
# image 46 processed
# image 47 processed
# image 48 processed
# ...

# %%
count = 1
for user in users:
    image_dir = os.path.join(data_dir,user,'4','binary')
    image_list = os.listdir(image_dir)
    for image in image_list:
        im = cv2.imread(os.path.join(image_dir,image))
        Full_frame_mask=np.zeros([480,640,3],dtype="uint8")
        Full_frame_mask[190:400,190:500] = im
        ht = Full_frame_mask.shape[0]
        wd = Full_frame_mask.shape[1]
        for i in range(ht):
            for j in range(wd):
                if Full_frame_mask[i][j][0] == 255:
                    Full_frame_mask[i][j][0] = 11
                    Full_frame_mask[i][j][1] = 11
                    Full_frame_mask[i][j][2] = 11
                else:
                    Full_frame_mask[i][j][0] = 1
                    Full_frame_mask[i][j][1] = 1
                    Full_frame_mask[i][j][2] = 1
        cv2.imwrite(os.path.join(root_dir,'modified_dataset','masks')+'/4_'+str(count)+'.png', Full_frame_mask)
        print('image {} processed'.format(count))
        count += 1
    print('User {} processed'.format(user))
# Out:
# image 1 processed
# image 2 processed
# image 3 processed
# image 4 processed
# image 5 processed
# image 6 processed
# image 7 processed
# image 8 processed
# image 9 processed
# image 10 processed
# image 11 processed
# image 12 processed
# image 13 processed
# image 14 processed
# image 15 processed
# image 16 processed
# image 17 processed
# image 18 processed
# image 19 processed
# image 20 processed
# image 21 processed
# image 22 processed
# image 23 processed
# image 24 processed
# image 25 processed
# image 26 processed
# image 27 processed
# image 28 processed
# image 29 processed
# image 30 processed
# image 31 processed
# image 32 processed
# image 33 processed
# image 34 processed
# image 35 processed
# image 36 processed
# image 37 processed
# image 38 processed
# image 39 processed
# image 40 processed
# image 41 processed
# image 42 processed
# image 43 processed
# image 44 processed
# image 45 processed
# image 46 processed
# image 47 processed
# image 48 processed
# ...

# %%
count = 1
for user in users:
    image_dir = os.path.join(data_dir,user,'5','binary')
    image_list = os.listdir(image_dir)
    for image in image_list:
        im = cv2.imread(os.path.join(image_dir,image))
        Full_frame_mask=np.zeros([480,640,3],dtype="uint8")
        Full_frame_mask[190:400,190:500] = im
        ht = Full_frame_mask.shape[0]
        wd = Full_frame_mask.shape[1]
        for i in range(ht):
            for j in range(wd):
                if Full_frame_mask[i][j][0] == 255:
                    Full_frame_mask[i][j][0] = 13
                    Full_frame_mask[i][j][1] = 13
                    Full_frame_mask[i][j][2] = 13
                else:
                    Full_frame_mask[i][j][0] = 1
                    Full_frame_mask[i][j][1] = 1
                    Full_frame_mask[i][j][2] = 1
        cv2.imwrite(os.path.join(root_dir,'modified_dataset','masks')+'/5_'+str(count)+'.png', Full_frame_mask)
        print('image {} processed'.format(count))
        count += 1
    print('User {} processed'.format(user))
# Out:
# image 1 processed
# image 2 processed
# image 3 processed
# image 4 processed
# image 5 processed
# image 6 processed
# image 7 processed
# image 8 processed
# image 9 processed
# image 10 processed
# image 11 processed
# image 12 processed
# image 13 processed
# image 14 processed
# image 15 processed
# image 16 processed
# image 17 processed
# image 18 processed
# image 19 processed
# image 20 processed
# image 21 processed
# image 22 processed
# image 23 processed
# image 24 processed
# image 25 processed
# image 26 processed
# image 27 processed
# image 28 processed
# image 29 processed
# image 30 processed
# image 31 processed
# image 32 processed
# image 33 processed
# image 34 processed
# image 35 processed
# image 36 processed
# image 37 processed
# image 38 processed
# image 39 processed
# image 40 processed
# image 41 processed
# image 42 processed
# image 43 processed
# image 44 processed
# image 45 processed
# image 46 processed
# image 47 processed
# image 48 processed
# ...

# %%
count = 1
for user in users:
    image_dir = os.path.join(data_dir,user,'6','binary')
    image_list = os.listdir(image_dir)
    for image in image_list:
        im = cv2.imread(os.path.join(image_dir,image))
        Full_frame_mask=np.zeros([480,640,3],dtype="uint8")
        Full_frame_mask[190:400,190:500] = im
        ht = Full_frame_mask.shape[0]
        wd = Full_frame_mask.shape[1]
        for i in range(ht):
            for j in range(wd):
                if Full_frame_mask[i][j][0] == 255:
                    Full_frame_mask[i][j][0] = 15
                    Full_frame_mask[i][j][1] = 15
                    Full_frame_mask[i][j][2] = 15
                else:
                    Full_frame_mask[i][j][0] = 1
                    Full_frame_mask[i][j][1] = 1
                    Full_frame_mask[i][j][2] = 1
        cv2.imwrite(os.path.join(root_dir,'modified_dataset','masks')+'/6_'+str(count)+'.png', Full_frame_mask)
        print('image {} processed'.format(count))
        count += 1
    print('User {} processed'.format(user))
# Out:
# image 1 processed
# image 2 processed
# image 3 processed
# image 4 processed
# image 5 processed
# image 6 processed
# image 7 processed
# image 8 processed
# image 9 processed
# image 10 processed
# image 11 processed
# image 12 processed
# image 13 processed
# image 14 processed
# image 15 processed
# image 16 processed
# image 17 processed
# image 18 processed
# image 19 processed
# image 20 processed
# image 21 processed
# image 22 processed
# image 23 processed
# image 24 processed
# image 25 processed
# image 26 processed
# image 27 processed
# image 28 processed
# image 29 processed
# image 30 processed
# image 31 processed
# image 32 processed
# image 33 processed
# image 34 processed
# image 35 processed
# image 36 processed
# image 37 processed
# image 38 processed
# image 39 processed
# image 40 processed
# image 41 processed
# image 42 processed
# image 43 processed
# image 44 processed
# image 45 processed
# image 46 processed
# image 47 processed
# image 48 processed
# ...

# %%
count = 1
for user in users:
    image_dir = os.path.join(data_dir,user,'7','binary')
    image_list = os.listdir(image_dir)
    for image in image_list:
        im = cv2.imread(os.path.join(image_dir,image))
        Full_frame_mask=np.zeros([480,640,3],dtype="uint8")
        Full_frame_mask[190:400,190:500] = im
        ht = Full_frame_mask.shape[0]
        wd = Full_frame_mask.shape[1]
        for i in range(ht):
            for j in range(wd):
                if Full_frame_mask[i][j][0] == 255:
                    Full_frame_mask[i][j][0] = 17
                    Full_frame_mask[i][j][1] = 17
                    Full_frame_mask[i][j][2] = 17
                else:
                    Full_frame_mask[i][j][0] = 1
                    Full_frame_mask[i][j][1] = 1
                    Full_frame_mask[i][j][2] = 1
        cv2.imwrite(os.path.join(root_dir,'modified_dataset','masks')+'/7_'+str(count)+'.png', Full_frame_mask)
        print('image {} processed'.format(count))
        count += 1
    print('User {} processed'.format(user))
# Out:
# image 1 processed
# image 2 processed
# image 3 processed
# image 4 processed
# image 5 processed
# image 6 processed
# image 7 processed
# image 8 processed
# image 9 processed
# image 10 processed
# image 11 processed
# image 12 processed
# image 13 processed
# image 14 processed
# image 15 processed
# image 16 processed
# image 17 processed
# image 18 processed
# image 19 processed
# image 20 processed
# image 21 processed
# image 22 processed
# image 23 processed
# image 24 processed
# image 25 processed
# image 26 processed
# image 27 processed
# image 28 processed
# image 29 processed
# image 30 processed
# image 31 processed
# image 32 processed
# image 33 processed
# image 34 processed
# image 35 processed
# image 36 processed
# image 37 processed
# image 38 processed
# image 39 processed
# image 40 processed
# image 41 processed
# image 42 processed
# image 43 processed
# image 44 processed
# image 45 processed
# image 46 processed
# image 47 processed
# image 48 processed
# ...

# %%
count = 1
for user in users:
    image_dir = os.path.join(data_dir,user,'8','binary')
    image_list = os.listdir(image_dir)
    for image in image_list:
        im = cv2.imread(os.path.join(image_dir,image))
        Full_frame_mask=np.zeros([480,640,3],dtype="uint8")
        Full_frame_mask[190:400,190:500] = im
        ht = Full_frame_mask.shape[0]
        wd = Full_frame_mask.shape[1]
        for i in range(ht):
            for j in range(wd):
                if Full_frame_mask[i][j][0] == 255:
                    Full_frame_mask[i][j][0] = 19
                    Full_frame_mask[i][j][1] = 19
                    Full_frame_mask[i][j][2] = 19
                else:
                    Full_frame_mask[i][j][0] = 1
                    Full_frame_mask[i][j][1] = 1
                    Full_frame_mask[i][j][2] = 1
        cv2.imwrite(os.path.join(root_dir,'modified_dataset','masks')+'/8_'+str(count)+'.png', Full_frame_mask)
        print('image {} processed'.format(count))
        count += 1
    print('User {} processed'.format(user))
# Out:
# image 1 processed
# image 2 processed
# image 3 processed
# image 4 processed
# image 5 processed
# image 6 processed
# image 7 processed
# image 8 processed
# image 9 processed
# image 10 processed
# image 11 processed
# image 12 processed
# image 13 processed
# image 14 processed
# image 15 processed
# image 16 processed
# image 17 processed
# image 18 processed
# image 19 processed
# image 20 processed
# image 21 processed
# image 22 processed
# image 23 processed
# image 24 processed
# image 25 processed
# image 26 processed
# image 27 processed
# image 28 processed
# image 29 processed
# image 30 processed
# image 31 processed
# image 32 processed
# image 33 processed
# image 34 processed
# image 35 processed
# image 36 processed
# image 37 processed
# image 38 processed
# image 39 processed
# image 40 processed
# image 41 processed
# image 42 processed
# image 43 processed
# image 44 processed
# image 45 processed
# image 46 processed
# image 47 processed
# image 48 processed
# ...

# %%
count = 1
for user in users:
    image_dir = os.path.join(data_dir,user,'9','binary')
    image_list = os.listdir(image_dir)
    for image in image_list:
        im = cv2.imread(os.path.join(image_dir,image))
        Full_frame_mask=np.zeros([480,640,3],dtype="uint8")
        Full_frame_mask[190:400,190:500] = im
        ht = Full_frame_mask.shape[0]
        wd = Full_frame_mask.shape[1]
        for i in range(ht):
            for j in range(wd):
                if Full_frame_mask[i][j][0] == 255:
                    Full_frame_mask[i][j][0] = 21
                    Full_frame_mask[i][j][1] = 21
                    Full_frame_mask[i][j][2] = 21
                else:
                    Full_frame_mask[i][j][0] = 1
                    Full_frame_mask[i][j][1] = 1
                    Full_frame_mask[i][j][2] = 1
        cv2.imwrite(os.path.join(root_dir,'modified_dataset','masks')+'/9_'+str(count)+'.png', Full_frame_mask)
        print('image {} processed'.format(count))
        count += 1
    print('User {} processed'.format(user))
# Out:
# image 1 processed
# image 2 processed
# image 3 processed
# image 4 processed
# image 5 processed
# image 6 processed
# image 7 processed
# image 8 processed
# image 9 processed
# image 10 processed
# image 11 processed
# image 12 processed
# image 13 processed
# image 14 processed
# image 15 processed
# image 16 processed
# image 17 processed
# image 18 processed
# image 19 processed
# image 20 processed
# image 21 processed
# image 22 processed
# image 23 processed
# image 24 processed
# image 25 processed
# image 26 processed
# image 27 processed
# image 28 processed
# image 29 processed
# image 30 processed
# image 31 processed
# image 32 processed
# image 33 processed
# image 34 processed
# image 35 processed
# image 36 processed
# image 37 processed
# image 38 processed
# image 39 processed
# image 40 processed
# image 41 processed
# image 42 processed
# image 43 processed
# image 44 processed
# image 45 processed
# image 46 processed
# image 47 processed
# image 48 processed
# ...

# %%
count = 1
for user in users:
    image_dir = os.path.join(data_dir,user,'A','binary')
    image_list = os.listdir(image_dir)
    for image in image_list:
        im = cv2.imread(os.path.join(image_dir,image))
        Full_frame_mask=np.zeros([480,640,3],dtype="uint8")
        Full_frame_mask[190:400,190:500] = im
        ht = Full_frame_mask.shape[0]
        wd = Full_frame_mask.shape[1]
        for i in range(ht):
            for j in range(wd):
                if Full_frame_mask[i][j][0] == 255:
                    Full_frame_mask[i][j][0] = 23
                    Full_frame_mask[i][j][1] = 23
                    Full_frame_mask[i][j][2] = 23
                else:
                    Full_frame_mask[i][j][0] = 1
                    Full_frame_mask[i][j][1] = 1
                    Full_frame_mask[i][j][2] = 1
        cv2.imwrite(os.path.join(root_dir,'modified_dataset','masks')+'/A_'+str(count)+'.png', Full_frame_mask)
        print('image {} processed'.format(count))
        count += 1
    print('User {} processed'.format(user))
# Out:
# image 1 processed
# image 2 processed
# image 3 processed
# image 4 processed
# image 5 processed
# image 6 processed
# image 7 processed
# image 8 processed
# image 9 processed
# image 10 processed
# image 11 processed
# image 12 processed
# image 13 processed
# image 14 processed
# image 15 processed
# image 16 processed
# image 17 processed
# image 18 processed
# image 19 processed
# image 20 processed
# image 21 processed
# image 22 processed
# image 23 processed
# image 24 processed
# image 25 processed
# image 26 processed
# image 27 processed
# image 28 processed
# image 29 processed
# image 30 processed
# image 31 processed
# image 32 processed
# image 33 processed
# image 34 processed
# image 35 processed
# image 36 processed
# image 37 processed
# image 38 processed
# image 39 processed
# image 40 processed
# image 41 processed
# image 42 processed
# image 43 processed
# image 44 processed
# image 45 processed
# image 46 processed
# image 47 processed
# image 48 processed
# ...

# %%
count = 1
for user in users:
    image_dir = os.path.join(data_dir,user,'B','binary')
    image_list = os.listdir(image_dir)
    for image in image_list:
        im = cv2.imread(os.path.join(image_dir,image))
        Full_frame_mask=np.zeros([480,640,3],dtype="uint8")
        Full_frame_mask[190:400,190:500] = im
        ht = Full_frame_mask.shape[0]
        wd = Full_frame_mask.shape[1]
        for i in range(ht):
            for j in range(wd):
                if Full_frame_mask[i][j][0] == 255:
                    Full_frame_mask[i][j][0] = 25
                    Full_frame_mask[i][j][1] = 25
                    Full_frame_mask[i][j][2] = 25
                else:
                    Full_frame_mask[i][j][0] = 1
                    Full_frame_mask[i][j][1] = 1
                    Full_frame_mask[i][j][2] = 1
        cv2.imwrite(os.path.join(root_dir,'modified_dataset','masks')+'/B_'+str(count)+'.png', Full_frame_mask)
        print('image {} processed'.format(count))
        count += 1
    print('User {} processed'.format(user))
# Out:
# image 1 processed
# image 2 processed
# image 3 processed
# image 4 processed
# image 5 processed
# image 6 processed
# image 7 processed
# image 8 processed
# image 9 processed
# image 10 processed
# image 11 processed
# image 12 processed
# image 13 processed
# image 14 processed
# image 15 processed
# image 16 processed
# image 17 processed
# image 18 processed
# image 19 processed
# image 20 processed
# image 21 processed
# image 22 processed
# image 23 processed
# image 24 processed
# image 25 processed
# image 26 processed
# image 27 processed
# image 28 processed
# image 29 processed
# image 30 processed
# image 31 processed
# image 32 processed
# image 33 processed
# image 34 processed
# image 35 processed
# image 36 processed
# image 37 processed
# image 38 processed
# image 39 processed
# image 40 processed
# image 41 processed
# image 42 processed
# image 43 processed
# image 44 processed
# image 45 processed
# image 46 processed
# image 47 processed
# image 48 processed
# ...

# %%
count = 1
for user in users:
    image_dir = os.path.join(data_dir,user,'C','binary')
    image_list = os.listdir(image_dir)
    for image in image_list:
        im = cv2.imread(os.path.join(image_dir,image))
        Full_frame_mask=np.zeros([480,640,3],dtype="uint8")
        Full_frame_mask[190:400,190:500] = im
        ht = Full_frame_mask.shape[0]
        wd = Full_frame_mask.shape[1]
        for i in range(ht):
            for j in range(wd):
                if Full_frame_mask[i][j][0] == 255:
                    Full_frame_mask[i][j][0] = 27
                    Full_frame_mask[i][j][1] = 27
                    Full_frame_mask[i][j][2] = 27
                else:
                    Full_frame_mask[i][j][0] = 1
                    Full_frame_mask[i][j][1] = 1
                    Full_frame_mask[i][j][2] = 1
        cv2.imwrite(os.path.join(root_dir,'modified_dataset','masks')+'/C_'+str(count)+'.png', Full_frame_mask)
        print('image {} processed'.format(count))
        count += 1
    print('User {} processed'.format(user))
# Out:
# image 1 processed
# image 2 processed
# image 3 processed
# image 4 processed
# image 5 processed
# image 6 processed
# image 7 processed
# image 8 processed
# image 9 processed
# image 10 processed
# image 11 processed
# image 12 processed
# image 13 processed
# image 14 processed
# image 15 processed
# image 16 processed
# image 17 processed
# image 18 processed
# image 19 processed
# image 20 processed
# image 21 processed
# image 22 processed
# image 23 processed
# image 24 processed
# image 25 processed
# image 26 processed
# image 27 processed
# image 28 processed
# image 29 processed
# image 30 processed
# image 31 processed
# image 32 processed
# image 33 processed
# image 34 processed
# image 35 processed
# image 36 processed
# image 37 processed
# image 38 processed
# image 39 processed
# image 40 processed
# image 41 processed
# image 42 processed
# image 43 processed
# image 44 processed
# image 45 processed
# image 46 processed
# image 47 processed
# image 48 processed
# ...

# %%
count = 1
for user in users:
    image_dir = os.path.join(data_dir,user,'D','binary')
    image_list = os.listdir(image_dir)
    for image in image_list:
        im = cv2.imread(os.path.join(image_dir,image))
        Full_frame_mask=np.zeros([480,640,3],dtype="uint8")
        Full_frame_mask[190:400,190:500] = im
        ht = Full_frame_mask.shape[0]
        wd = Full_frame_mask.shape[1]
        for i in range(ht):
            for j in range(wd):
                if Full_frame_mask[i][j][0] == 255:
                    Full_frame_mask[i][j][0] = 29
                    Full_frame_mask[i][j][1] = 29
                    Full_frame_mask[i][j][2] = 29
                else:
                    Full_frame_mask[i][j][0] = 1
                    Full_frame_mask[i][j][1] = 1
                    Full_frame_mask[i][j][2] = 1
        cv2.imwrite(os.path.join(root_dir,'modified_dataset','masks')+'/D_'+str(count)+'.png', Full_frame_mask)
        print('image {} processed'.format(count))
        count += 1
    print('User {} processed'.format(user))
# Out:
# image 1 processed
# image 2 processed
# image 3 processed
# image 4 processed
# image 5 processed
# image 6 processed
# image 7 processed
# image 8 processed
# image 9 processed
# image 10 processed
# image 11 processed
# image 12 processed
# image 13 processed
# image 14 processed
# image 15 processed
# image 16 processed
# image 17 processed
# image 18 processed
# image 19 processed
# image 20 processed
# image 21 processed
# image 22 processed
# image 23 processed
# image 24 processed
# image 25 processed
# image 26 processed
# image 27 processed
# image 28 processed
# image 29 processed
# image 30 processed
# image 31 processed
# image 32 processed
# image 33 processed
# image 34 processed
# image 35 processed
# image 36 processed
# image 37 processed
# image 38 processed
# image 39 processed
# image 40 processed
# image 41 processed
# image 42 processed
# image 43 processed
# image 44 processed
# image 45 processed
# image 46 processed
# image 47 processed
# image 48 processed
# ...

# %%
count = 1
for user in users:
    image_dir = os.path.join(data_dir,user,'E','binary')
    image_list = os.listdir(image_dir)
    for image in image_list:
        im = cv2.imread(os.path.join(image_dir,image))
        Full_frame_mask=np.zeros([480,640,3],dtype="uint8")
        Full_frame_mask[190:400,190:500] = im
        ht = Full_frame_mask.shape[0]
        wd = Full_frame_mask.shape[1]
        for i in range(ht):
            for j in range(wd):
                if Full_frame_mask[i][j][0] == 255:
                    Full_frame_mask[i][j][0] = 31
                    Full_frame_mask[i][j][1] = 31
                    Full_frame_mask[i][j][2] = 31
                else:
                    Full_frame_mask[i][j][0] = 1
                    Full_frame_mask[i][j][1] = 1
                    Full_frame_mask[i][j][2] = 1
        cv2.imwrite(os.path.join(root_dir,'modified_dataset','masks')+'/E_'+str(count)+'.png', Full_frame_mask)
        print('image {} processed'.format(count))
        count += 1
    print('User {} processed'.format(user))
# Out:
# image 1 processed
# image 2 processed
# image 3 processed
# image 4 processed
# image 5 processed
# image 6 processed
# image 7 processed
# image 8 processed
# image 9 processed
# image 10 processed
# image 11 processed
# image 12 processed
# image 13 processed
# image 14 processed
# image 15 processed
# image 16 processed
# image 17 processed
# image 18 processed
# image 19 processed
# image 20 processed
# image 21 processed
# image 22 processed
# image 23 processed
# image 24 processed
# image 25 processed
# image 26 processed
# image 27 processed
# image 28 processed
# image 29 processed
# image 30 processed
# image 31 processed
# image 32 processed
# image 33 processed
# image 34 processed
# image 35 processed
# image 36 processed
# image 37 processed
# image 38 processed
# image 39 processed
# image 40 processed
# image 41 processed
# image 42 processed
# image 43 processed
# image 44 processed
# image 45 processed
# image 46 processed
# image 47 processed
# image 48 processed
# ...

# %%
count = 1
for user in users:
    image_dir = os.path.join(data_dir,user,'F','binary')
    image_list = os.listdir(image_dir)
    for image in image_list:
        im = cv2.imread(os.path.join(image_dir,image))
        Full_frame_mask=np.zeros([480,640,3],dtype="uint8")
        Full_frame_mask[190:400,190:500] = im
        ht = Full_frame_mask.shape[0]
        wd = Full_frame_mask.shape[1]
        for i in range(ht):
            for j in range(wd):
                if Full_frame_mask[i][j][0] == 255:
                    Full_frame_mask[i][j][0] = 33
                    Full_frame_mask[i][j][1] = 33
                    Full_frame_mask[i][j][2] = 33
                else:
                    Full_frame_mask[i][j][0] = 1
                    Full_frame_mask[i][j][1] = 1
                    Full_frame_mask[i][j][2] = 1
        cv2.imwrite(os.path.join(root_dir,'modified_dataset','masks')+'/F_'+str(count)+'.png', Full_frame_mask)
        print('image {} processed'.format(count))
        count += 1
    print('User {} processed'.format(user))
# Out:
# image 1 processed
# image 2 processed
# image 3 processed
# image 4 processed
# image 5 processed
# image 6 processed
# image 7 processed
# image 8 processed
# image 9 processed
# image 10 processed
# image 11 processed
# image 12 processed
# image 13 processed
# image 14 processed
# image 15 processed
# image 16 processed
# image 17 processed
# image 18 processed
# image 19 processed
# image 20 processed
# image 21 processed
# image 22 processed
# image 23 processed
# image 24 processed
# image 25 processed
# image 26 processed
# image 27 processed
# image 28 processed
# image 29 processed
# image 30 processed
# image 31 processed
# image 32 processed
# image 33 processed
# image 34 processed
# image 35 processed
# image 36 processed
# image 37 processed
# image 38 processed
# image 39 processed
# image 40 processed
# image 41 processed
# image 42 processed
# image 43 processed
# image 44 processed
# image 45 processed
# image 46 processed
# image 47 processed
# image 48 processed
# ...

# %%
count = 1
for user in users:
    image_dir = os.path.join(data_dir,user,'G','binary')
    image_list = os.listdir(image_dir)
    for image in image_list:
        im = cv2.imread(os.path.join(image_dir,image))
        Full_frame_mask=np.zeros([480,640,3],dtype="uint8")
        Full_frame_mask[190:400,190:500] = im
        ht = Full_frame_mask.shape[0]
        wd = Full_frame_mask.shape[1]
        for i in range(ht):
            for j in range(wd):
                if Full_frame_mask[i][j][0] == 255:
                    Full_frame_mask[i][j][0] = 35
                    Full_frame_mask[i][j][1] = 35
                    Full_frame_mask[i][j][2] = 35
                else:
                    Full_frame_mask[i][j][0] = 1
                    Full_frame_mask[i][j][1] = 1
                    Full_frame_mask[i][j][2] = 1
        cv2.imwrite(os.path.join(root_dir,'modified_dataset','masks')+'/G_'+str(count)+'.png', Full_frame_mask)
        print('image {} processed'.format(count))
        count += 1
    print('User {} processed'.format(user))
# Out:
# image 1 processed
# image 2 processed
# image 3 processed
# image 4 processed
# image 5 processed
# image 6 processed
# image 7 processed
# image 8 processed
# image 9 processed
# image 10 processed
# image 11 processed
# image 12 processed
# image 13 processed
# image 14 processed
# image 15 processed
# image 16 processed
# image 17 processed
# image 18 processed
# image 19 processed
# image 20 processed
# image 21 processed
# image 22 processed
# image 23 processed
# image 24 processed
# image 25 processed
# image 26 processed
# image 27 processed
# image 28 processed
# image 29 processed
# image 30 processed
# image 31 processed
# image 32 processed
# image 33 processed
# image 34 processed
# image 35 processed
# image 36 processed
# image 37 processed
# image 38 processed
# image 39 processed
# image 40 processed
# image 41 processed
# image 42 processed
# image 43 processed
# image 44 processed
# image 45 processed
# image 46 processed
# image 47 processed
# image 48 processed
# ...

# %%
count = 1
for user in users:
    image_dir = os.path.join(data_dir,user,'H','binary')
    image_list = os.listdir(image_dir)
    for image in image_list:
        im = cv2.imread(os.path.join(image_dir,image))
        Full_frame_mask=np.zeros([480,640,3],dtype="uint8")
        Full_frame_mask[190:400,190:500] = im
        ht = Full_frame_mask.shape[0]
        wd = Full_frame_mask.shape[1]
        for i in range(ht):
            for j in range(wd):
                if Full_frame_mask[i][j][0] == 255:
                    Full_frame_mask[i][j][0] = 37
                    Full_frame_mask[i][j][1] = 37
                    Full_frame_mask[i][j][2] = 37
                else:
                    Full_frame_mask[i][j][0] = 1
                    Full_frame_mask[i][j][1] = 1
                    Full_frame_mask[i][j][2] = 1
        cv2.imwrite(os.path.join(root_dir,'modified_dataset','masks')+'/H_'+str(count)+'.png', Full_frame_mask)
        print('image {} processed'.format(count))
        count += 1
    print('User {} processed'.format(user))
# Out:
# image 1 processed
# image 2 processed
# image 3 processed
# image 4 processed
# image 5 processed
# image 6 processed
# image 7 processed
# image 8 processed
# image 9 processed
# image 10 processed
# image 11 processed
# image 12 processed
# image 13 processed
# image 14 processed
# image 15 processed
# image 16 processed
# image 17 processed
# image 18 processed
# image 19 processed
# image 20 processed
# image 21 processed
# image 22 processed
# image 23 processed
# image 24 processed
# image 25 processed
# image 26 processed
# image 27 processed
# image 28 processed
# image 29 processed
# image 30 processed
# image 31 processed
# image 32 processed
# image 33 processed
# image 34 processed
# image 35 processed
# image 36 processed
# image 37 processed
# image 38 processed
# image 39 processed
# image 40 processed
# image 41 processed
# image 42 processed
# image 43 processed
# image 44 processed
# image 45 processed
# image 46 processed
# image 47 processed
# image 48 processed
# ...

# %%
count = 1
for user in users:
    image_dir = os.path.join(data_dir,user,'I','binary')
    image_list = os.listdir(image_dir)
    for image in image_list:
        im = cv2.imread(os.path.join(image_dir,image))
        Full_frame_mask=np.zeros([480,640,3],dtype="uint8")
        Full_frame_mask[190:400,190:500] = im
        ht = Full_frame_mask.shape[0]
        wd = Full_frame_mask.shape[1]
        for i in range(ht):
            for j in range(wd):
                if Full_frame_mask[i][j][0] == 255:
                    Full_frame_mask[i][j][0] = 39
                    Full_frame_mask[i][j][1] = 39
                    Full_frame_mask[i][j][2] = 39
                else:
                    Full_frame_mask[i][j][0] = 1
                    Full_frame_mask[i][j][1] = 1
                    Full_frame_mask[i][j][2] = 1
        cv2.imwrite(os.path.join(root_dir,'modified_dataset','masks')+'/I_'+str(count)+'.png', Full_frame_mask)
        print('image {} processed'.format(count))
        count += 1
    print('User {} processed'.format(user))
# Out:
# image 1 processed
# image 2 processed
# image 3 processed
# image 4 processed
# image 5 processed
# image 6 processed
# image 7 processed
# image 8 processed
# image 9 processed
# image 10 processed
# image 11 processed
# image 12 processed
# image 13 processed
# image 14 processed
# image 15 processed
# image 16 processed
# image 17 processed
# image 18 processed
# image 19 processed
# image 20 processed
# image 21 processed
# image 22 processed
# image 23 processed
# image 24 processed
# image 25 processed
# image 26 processed
# image 27 processed
# image 28 processed
# image 29 processed
# image 30 processed
# image 31 processed
# image 32 processed
# image 33 processed
# image 34 processed
# image 35 processed
# image 36 processed
# image 37 processed
# image 38 processed
# image 39 processed
# image 40 processed
# image 41 processed
# image 42 processed
# image 43 processed
# image 44 processed
# image 45 processed
# image 46 processed
# image 47 processed
# image 48 processed
# ...

# %%
import numpy as np
