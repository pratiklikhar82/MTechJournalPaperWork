# %%
import os
import cv2

# %%
root_dir = '/Users/pratiklikhar/Documents/MTech_Project'

# %%
dirs = ['test','test_annot','train','train_annot','val','val_annot']

# %%
for direc in dirs:
    path = os.path.join(root_dir,'data',direc)
    img_list = os.listdir(path)
    #print(img_list)
    for img in img_list:
        print(img)
        im = cv2.imread(os.path.join(root_dir,'data',direc,img))
        lst = img.split('_')
        #print(lst[1])
        if lst[0] == '0':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'zero'+lst[1]), im)
            # !rm $img
        elif lst[0] == '1':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'one'+lst[1]), im)
            # !rm $img
        elif lst[0] == '2':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'two'+lst[1]), im)
            # !rm $img
        elif lst[0] == '3':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'three'+lst[1]), im)
            # !rm $img
        elif lst[0] == '4':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'four'+lst[1]), im)
            # !rm $img
        elif lst[0] == '5':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'five'+lst[1]), im)
            # !rm $img
        elif lst[0] == '6':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'six'+lst[1]), im)
            # !rm $img
        elif lst[0] == '7':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'seven'+lst[1]), im)
            # !rm $img
        elif lst[0] == '8':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'eight'+lst[1]), im)
            # !rm $img
        elif lst[0] == '9':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'nine'+lst[1]), im)
            # !rm $img
        elif lst[0] == 'A':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'A'+lst[1]), im)
            # !rm $img
        elif lst[0] == 'B':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'B'+lst[1]), im)
            # !rm $img
        elif lst[0] == 'C':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'C'+lst[1]), im)
            # !rm $img
        elif lst[0] == 'D':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'D'+lst[1]), im)
            # !rm $img
        elif lst[0] == 'E':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'E'+lst[1]), im)
            # !rm $img
        elif lst[0] == 'F':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'F'+lst[1]), im)
            # !rm $img
        elif lst[0] == 'G':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'G'+lst[1]), im)
            # !rm $img
        elif lst[0] == 'H':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'H'+lst[1]), im)
            # !rm $img
        elif lst[0] == 'I':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'I'+lst[1]), im)
            # !rm $img
        elif lst[0] == 'J':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'J'+lst[1]), im)
            # !rm $img
        elif lst[0] == 'K':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'K'+lst[1]), im)
            # !rm $img
        elif lst[0] == 'L':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'L'+lst[1]), im)
            # !rm $img
        elif lst[0] == 'M':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'M'+lst[1]), im)
            # !rm $img
        elif lst[0] == 'N':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'N'+lst[1]), im)
            # !rm $img
        elif lst[0] == 'O':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'O'+lst[1]), im)
            # !rm $img
        elif lst[0] == 'P':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'P'+lst[1]), im)
            # !rm $img
        elif lst[0] == 'Q':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'Q'+lst[1]), im)
            # !rm $img
        elif lst[0] == 'R':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'R'+lst[1]), im)
            # !rm $img
        elif lst[0] == 'S':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'S'+lst[1]), im)
            # !rm $img
        elif lst[0] == 'T':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'T'+lst[1]), im)
            # !rm $img
        elif lst[0] == 'U':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'U'+lst[1]), im)
            # !rm $img
        elif lst[0] == 'V':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'V'+lst[1]), im)
            # !rm $img
        elif lst[0] == 'W':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'W'+lst[1]), im)
            # !rm $img
        elif lst[0] == 'X':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'X'+lst[1]), im)
            # !rm $img
        elif lst[0] == 'Y':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'Y'+lst[1]), im)
            # !rm $img
        elif lst[0] == 'Z':
            cv2.imwrite(os.path.join(root_dir,'data',direc,'Z'+lst[1]), im)
            # !rm $img
    print('{} processed'.format(direc))
# Out:
# Y_784.png
# rm: Y_784.png: No such file or directory
# F_877.png
# rm: F_877.png: No such file or directory
# 0_833.png
# rm: 0_833.png: No such file or directory
# N_911.png
# rm: N_911.png: No such file or directory
# 8_955.png
# rm: 8_955.png: No such file or directory
# H_983.png
# rm: H_983.png: No such file or directory
# 8_83.png
# rm: 8_83.png: No such file or directory
# K_840.png
# rm: K_840.png: No such file or directory
# C_926.png
# rm: C_926.png: No such file or directory
# P_85.png
# rm: P_85.png: No such file or directory
# 5_962.png
# rm: 5_962.png: No such file or directory
# C_932.png
# rm: C_932.png: No such file or directory
# P_91.png
# rm: P_91.png: No such file or directory
# 5_976.png
# rm: 5_976.png: No such file or directory
# H_997.png
# rm: H_997.png: No such file or directory
# 8_97.png
# rm: 8_97.png: No such file or directory
# K_854.png
# rm: K_854.png: No such file or directory
# 8_799.png
# rm: 8_799.png: No such file or directory
# N_905.png
# ...
